# %% [markdown]
# # Taller 3 Árboles y redes
#
# William Andres Talero Bermudez
#
# Juan Sebastian Velasquez Castañeda

# %% [markdown]
# ## Importar librerias

# %%
# !pip install networkx
# !pip install pyvis
# !pip install plotly

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt

# %% [markdown]
# # Cargar la base
#
# Adyacencias de palabras : red de adyacencias de adjetivos y sustantivos comunes en la novela David Copperfield de Charles Dickens. Por favor cite MEJ Newman, Phys. Rev. E 74 , 036104 (2006).

# %%
g = nx.read_gml('dolphins.gml')

# %%
print("Número de nodos:", g.number_of_nodes())
print("Número de nodos:", g.number_of_edges())
# Out:
# Número de nodos: 62
# Número de nodos: 159

# %%
list(g.nodes)
# Out:
# ['Beak',
#  'Beescratch',
#  'Bumper',
#  'CCL',
#  'Cross',
#  'DN16',
#  'DN21',
#  'DN63',
#  'Double',
#  'Feather',
#  'Fish',
#  'Five',
#  'Fork',
#  'Gallatin',
#  'Grin',
#  'Haecksel',
#  'Hook',
#  'Jet',
#  'Jonah',
#  'Knit',
#  'Kringel',
#  'MN105',
#  'MN23',
#  'MN60',
#  'MN83',
#  'Mus',
#  'Notch',
#  'Number1',
#  'Oscar',
#  'Patchback',
#  'PL',
#  'Quasi',
#  'Ripplefluke',
#  'Scabs',
#  'Shmuddel',
#  'SMN5',
#  'SN100',
#  'SN4',
#  'SN63',
#  'SN89',
#  'SN9',
#  'SN90',
#  'SN96',
#  'Stripes',
#  'Thumper',
#  'Topless',
#  'TR120',
#  'TR77',
#  'TR82',
#  'TR88',
#  'TR99',
#  'Trigger',
#  'TSN103',
#  'TSN83',
#  'Upbang',
#  'Vau',
#  'Wave',
#  'Web',
#  'Whitetip',
#  'Zap',
#  'Zig',
#  'Zipfel']

# %%
list(g.edges)
# Out:
# [('Beak', 'Fish'),
#  ('Beak', 'Grin'),
#  ('Beak', 'Haecksel'),
#  ('Beak', 'SN9'),
#  ('Beak', 'SN96'),
#  ('Beak', 'TR77'),
#  ('Beescratch', 'Jet'),
#  ('Beescratch', 'Knit'),
#  ('Beescratch', 'Notch'),
#  ('Beescratch', 'Number1'),
#  ('Beescratch', 'Oscar'),
#  ('Beescratch', 'SN100'),
#  ('Beescratch', 'SN90'),
#  ('Beescratch', 'Upbang'),
#  ('Bumper', 'Fish'),
#  ('Bumper', 'SN96'),
#  ('Bumper', 'Thumper'),
#  ('Bumper', 'Zipfel'),
#  ('CCL', 'Double'),
#  ('CCL', 'Grin'),
#  ('CCL', 'Zap'),
#  ('Cross', 'Trigger'),
#  ('DN16', 'Feather'),
#  ('DN16', 'Gallatin'),
#  ('DN16', 'Wave'),
#  ('DN16', 'Web'),
#  ('DN21', 'Feather'),
#  ('DN21', 'Gallatin'),
#  ('DN21', 'Jet'),
#  ('DN21', 'Upbang'),
#  ('DN21', 'Wave'),
#  ('DN21', 'Web'),
#  ('DN63', 'Knit'),
#  ('DN63', 'Number1'),
#  ('DN63', 'PL'),
#  ('DN63', 'SN9'),
#  ('DN63', 'Upbang'),
#  ('Double', 'Kringel'),
#  ('Double', 'Oscar'),
#  ('Double', 'SN4'),
#  ('Double', 'Topless'),
#  ('Double', 'Zap'),
# ...

# %% [markdown]
# # Red Dolphins
#
# Los delfines nariz de botella (especie Tursiops ) de Shark Bay, Australia, viven en una sociedad de fisión-fusión altamente social. Los investigadores estudian que los delfines pueden obtener información sobre los diferentes patrones de alimentación, socialización y cuidado de las crías que son evidentes. Algunos delfines tienen lazos muy estrechos con algunos amigos, algunos son relativamente solitarios mientras que otros son mariposas sociales. Algunos cazan con herramientas y otros van a la playa para pescar.

# %% [markdown]
# # ¿Que?
#
# **¿Que?:El usuario observa un grupo de delfines nariz de botella (64 individuos).**

# %% [markdown]
# # ¿Por qué?
#
# **¿POR QUÉ?: Brindar información sobre las prácticas de socialización de los delfines.**

# %% [markdown]
# # Red Dolphins

# %%
plt.figure(figsize=(50,20))
plt.subplot(121)
nx.draw(g, with_labels=True,width=1,node_size=500,node_shape="s",alpha=0.8,linewidths=40,node_color='lightblue')

# %% [markdown]
# ### Canales:
#
# 1) Color: lightblue
# 2) Tamaño de los nodos: 500

# %% [markdown]
# Los resultados de estas redes de actividad ponderada indican que las redes pueden revelar patrones detallados de delfines nariz de botella a nivel de población; los delfines socializan en grandes grupos con asociaciones preferenciales luego se puden inferir que se dispersan para buscar alimento en grupos muy pequeños y débilmente conectados.
